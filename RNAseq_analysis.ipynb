# %% [markdown]
# # RNA-seq analysis
#
# Data processed with nf-core pipeline (Salmon mapper).
#
# Then performed differential expression analysis with DESeq2.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import scipy.stats
import os
from adjustText import adjust_text
import matplotlib.patheffects as PathEffects
import warnings
warnings.filterwarnings('ignore')
plt.rc('font', family='Helvetica')

# %%
tx2gene = pd.read_csv("rnaseq_data_deseq2/tx2gene.tsv", sep='\t')

gene_name_dict = dict(zip(tx2gene['gene_id'], tx2gene['gene_name']))

# %%
#df = pd.read_csv('rnaseq_data_deseq2/NT_24hours_vs_NT_no_drug.csv').rename(columns={'Unnamed: 0':'gene_id'})

df = pd.read_csv('rnaseq_data_deseq2/L156F_no_drug_vs_NT_no_drug.csv').rename(columns={'Unnamed: 0':'gene_id'})


df['gene_name'] = [gene_name_dict[i] for i in df['gene_id']]



df2 = df[df['baseMean']>=50]

df2 = df2.set_index('gene_name')

# %%
df2.sort_values(by='padj', ascending=True)[:40]
# Out:
#                       gene_id      baseMean  log2FoldChange     lfcSE  \
# gene_name
# TNS1       ENSG00000079308.21   1999.362624       -2.222871  0.123384
# CCDC80     ENSG00000091986.16   7845.887075       -1.640915  0.103159
# USH1C      ENSG00000006611.17    428.185925       -2.757662  0.175085
# COL5A1     ENSG00000130635.17   6904.394173       -1.987472  0.133448
# TAGLN      ENSG00000149591.17   1441.438764       -2.513226  0.169343
# CHGB       ENSG00000089199.10    761.419573        2.014540  0.143720
# SEMA3A     ENSG00000075213.11    971.410666        1.950907  0.140927
# VCAN       ENSG00000038427.16   1581.662241       -1.693417  0.124251
# LBH        ENSG00000213626.13   6649.578536       -1.419740  0.105425
# CA9        ENSG00000107159.14    478.378543       -2.114198  0.160459
# CES1       ENSG00000198848.13    530.913153        2.209433  0.168758
# COL4A1     ENSG00000187498.17   3797.642752       -2.140666  0.164579
# CLDN2      ENSG00000165376.12   4510.206521       -1.440997  0.111662
# ANXA8       ENSG00000265190.7   1355.327165       -1.574124  0.125627
# IL11        ENSG00000095752.7   2753.612853       -2.042230  0.165987
# CCBE1      ENSG00000183287.15    371.156669       -2.194612  0.184629
# SLC7A7     ENSG00000155465.21   1231.002574       -1.752601  0.151628
# MATN2      ENSG00000132561.14   1790.717693       -1.438885  0.125142
# ANXA8L1     ENSG00000264230.9   3716.712069       -1.308598  0.114149
# PARM1      ENSG00000169116.11    279.406321        2.374164  0.212673
# HNF4A      ENSG00000101076.20   2049.042026       -1.637046  0.147022
# AQP3       ENSG00000165272.16    796.106866        2.039623  0.183523
# MARCHF4     ENSG00000144583.5    362.025628       -2.030428  0.187364
# DCDC1      ENSG00000170959.15    222.675034       -2.471829  0.229043
# TPM1       ENSG00000140416.26  25582.480108       -1.100177  0.102862
# NTRK3      ENSG00000140538.17   6258.743416       -1.170762  0.109548
# ST6GAL2    ENSG00000144057.16    959.772853       -1.606067  0.151139
# SLC17A3    ENSG00000124564.17    158.846627       -2.785527  0.262699
# FLJ16779    ENSG00000275620.1     82.860512       -4.067073  0.388920
# TRIM31     ENSG00000204616.11    172.268130       -2.250812  0.215844
df3[df3['gene_name']=='CDK9']
# Out:
#      gene_name             gene_id     baseMean  log2FoldChange     lfcSE  \
# 5335      CDK9  ENSG00000136807.14  1944.945496          0.3125  0.083731
#
#           stat   pvalue      padj
# 5335  3.732184  0.00019  0.000893

# %%
plt.scatter(df2['log2FoldChange'], -np.log10(df2['padj']))

# %%
df = pd.read_csv('rnaseq_data_deseq2/L156F_no_drug_vs_NT_no_drug.csv').rename(columns={'Unnamed: 0':'gene_id'})


df['gene_name'] = [gene_name_dict[i] for i in df['gene_id']]


df = df.dropna()
plt.scatter(np.log10(df['baseMean']),df['log2FoldChange'])

# %%
df[(df['padj']<=.01) & (df['baseMean']>=50) & (df['log2FoldChange']<=-1)].sort_values(by='log2FoldChange', ascending=True)[50:100]
# Out:
#                   gene_id     baseMean  log2FoldChange     lfcSE       stat  \
# 6324   ENSG00000134198.10    62.512756       -1.673378  0.440021  -3.802954
# 18746   ENSG00000230479.2    61.148745       -1.659447  0.346598  -4.787809
# 16774  ENSG00000215481.10   124.119860       -1.656239  0.282063  -5.871879
# 12041  ENSG00000172602.11   815.880453       -1.646578  0.166696  -9.877703
# 1850   ENSG00000091986.16  7845.887075       -1.640915  0.103159 -15.906610
# 2301   ENSG00000101076.20  2049.042026       -1.637046  0.147022 -11.134670
# 11366   ENSG00000168955.4  1711.435937       -1.632441  0.217860  -7.493086
# 8511   ENSG00000149564.12   270.795688       -1.630119  0.181407  -8.985956
# 27103   ENSG00000277268.3   108.924964       -1.623530  0.290924  -5.580607
# 31110   ENSG00000293925.1    88.949306       -1.609334  0.294800  -5.459065
# 7874   ENSG00000144057.16   959.772853       -1.606067  0.151139 -10.626426
# 23285   ENSG00000258128.3    56.891761       -1.580012  0.326874  -4.833698
# 3975   ENSG00000114115.11    74.004474       -1.579858  0.336994  -4.688096
# 24767   ENSG00000265190.7  1355.327165       -1.574124  0.125627 -12.530158
# 7174   ENSG00000139132.16   205.060860       -1.567965  0.254501  -6.160944
# 6942   ENSG00000137731.14   332.544519       -1.561947  0.232738  -6.711181
# 20078  ENSG00000236404.13    59.371591       -1.552555  0.356025  -4.360808
# 12827  ENSG00000177822.11    80.550304       -1.530415  0.421981  -3.626736
# 27325   ENSG00000278709.2   295.138215       -1.522900  0.201268  -7.566518
# 13925  ENSG00000184985.17   228.720519       -1.479499  0.286562  -5.162931
# 14473  ENSG00000188112.10   132.708924       -1.477121  0.291869  -5.060907
# 9215    ENSG00000156804.7   123.293648       -1.471488  0.255771  -5.753155
# 1963   ENSG00000099139.14   223.732355       -1.469202  0.214346  -6.854339
# 4097   ENSG00000115221.13   222.417965       -1.463152  0.244142  -5.993023
# 12461   ENSG00000175311.7    83.967436       -1.450795  0.291051  -4.984669
# 11537   ENSG00000169903.7  2407.374600       -1.450604  0.148016  -9.800317
# 3870   ENSG00000113140.11   491.339032       -1.443576  0.246701  -5.851519
# 383    ENSG00000021645.20   181.692531       -1.442951  0.222813  -6.476047
# 10589  ENSG00000165376.12  4510.206521       -1.440997  0.111662 -12.904990
# 11537  1.122329e-22  5.733584e-20           TM4SF4
# 3870   4.871029e-09  4.513343e-07            SPARC
# 383    9.415654e-11  1.191893e-08            NRXN3
# 10589  4.218728e-38  6.134030e-35            CLDN2
# 6113   1.350393e-30  1.418063e-27            MATN2
# 27705  7.677182e-07  4.656945e-05  ENSG00000279821
# 16364  2.451740e-41  5.149199e-38              LBH
# 6472   1.759145e-14  3.958495e-12            HNF1A
# 25557  1.201881e-04  3.863598e-03         KCNQ1OT1
# 4998   1.458250e-05  6.026519e-04            ITIH5
# 3452   3.024162e-04  8.308534e-03            TRIM2
# 2332   3.763025e-07  2.469746e-05            BIRC7
# 363    1.030988e-19  4.236465e-17           PHLDB1
# 6146   2.377039e-05  9.203699e-04             ACY3
# 30030  4.731668e-06  2.342932e-04  ENSG00000289850
# 7281   6.336338e-08  4.810018e-06            RAB20
# 2150   1.245663e-20  5.742808e-18            APOL1
# 7663   2.005666e-09  2.049248e-07          TINAGL1
# 13720  1.434668e-06  8.048952e-05          B3GALT5
# 11416  6.789216e-19  2.467880e-16            RAB3B
# 9028   1.049326e-16  2.960353e-14           PIEZO2
# 20728  2.343955e-15  5.829663e-13           PLCXD2
# 6071   1.798826e-08  1.511174e-06            PTPRE
# 17867  1.803126e-04  5.375819e-03            TEX41
# 896    3.297252e-04  8.967576e-03          COL17A1

# %%
df[df['gene_name']=='MYC']
# Out:
#                  gene_id     baseMean  log2FoldChange     lfcSE      stat  \
# 6822  ENSG00000136997.22  5949.488122        0.127671  0.138767  0.920043
#
#        pvalue      padj gene_name
# 6822  0.35755  0.838594       MYC

# %% [markdown]
# # GSEA

# %%
import gseapy as gs

# %%
ranking
# Out:
#             stat
# 263    42.918354
# 30519  42.833000
# 5283   42.029561
# 9672   38.947105
# 3278   38.047522
# ...          ...
# 15252 -31.832521
# 3309  -32.862023
# 2370  -36.939526
# 10777 -38.382564
# 14595 -50.052561
#
# [13954 rows x 1 columns]

# %%
df = pd.read_csv('rnaseq_data_deseq2/L156F_no_drug_vs_NT_no_drug.csv').rename(columns={'Unnamed: 0':'gene_id'})
df['gene_name'] = [gene_name_dict[i] for i in df['gene_id']]



df2 = df[df['baseMean']>=50]

df2 = df2.set_index('gene_name')

# %%
# Prepare the input: the GSEA input expects a series with gene names as the index and log2FoldChange as the values
ranking = df2[["stat"]]
ranking = ranking.sort_values("stat", ascending=False)
ranking

# Run pre-ranked GSEA
pre_res = gs.prerank(
    rnk=ranking,
    gene_sets='KEGG_2021_Human',  # or "GO_Biological_Process_2018", etc.'KEGG_2021_Human'
    outdir="gsea_output",   # output directory
    permutation_num=100,    # reduce for speed, increase for publication
    seed=42
)
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
a = pre_res.res2d

b = a[a['FDR q-val']<.25]

b[:20]
# Out:
#        Name                                               Term        ES  \
# 0   prerank                                  Adherens junction -0.563241
# 1   prerank                           ECM-receptor interaction -0.622077
# 2   prerank                                     Focal adhesion -0.497291
# 3   prerank                                     Tight junction -0.484618
# 4   prerank                            Cell adhesion molecules  -0.51562
# 5   prerank                   Protein digestion and absorption -0.635435
# 7   prerank                         PI3K-Akt signaling pathway -0.409894
# 9   prerank                     Human papillomavirus infection -0.408747
# 10  prerank                            IL-17 signaling pathway  0.451166
# 11  prerank    Arrhythmogenic right ventricular cardiomyopathy -0.503416
# 12  prerank  AGE-RAGE signaling pathway in diabetic complic... -0.461038
# 13  prerank                                        Ferroptosis  0.508525
# 14  prerank                   Regulation of actin cytoskeleton -0.414664
# 15  prerank                             Fanconi anemia pathway  0.422501
# 16  prerank                          Selenocompound metabolism   0.57955
# 17  prerank             Various types of N-glycan biosynthesis  0.495986
# 18  prerank              Carbohydrate digestion and absorption -0.538024
# 19  prerank                             Small cell lung cancer -0.449428
# 20  prerank                                 Mineral absorption -0.513475
# 21  prerank                  Thyroid hormone signaling pathway -0.439406
#
#          NES NOM p-val FDR q-val FWER p-val   Tag %  Gene %  \
# 0   -2.03265       0.0  0.010952       0.01   26/61  17.28%
# 1  -2.013058       0.0  0.010952       0.02   22/51   8.67%
# 2  -1.916495       0.0  0.014603       0.04  43/148   9.78%
# 3  -1.894268       0.0   0.01369       0.05  42/125  17.29%
# 4  -1.784977       0.0   0.04819        0.2   17/63  10.87%
# 5  -1.777461       0.0  0.049285       0.23   15/40   5.05%
# 7  -1.672456       0.0  0.129862       0.43  44/221   9.04%
# 9   -1.63729       0.0  0.168391       0.55  83/248  19.45%
# 10  1.637116       0.0  0.225414       0.44   12/58   7.03%
# 11 -1.636616  0.016667  0.149681       0.55   21/49  11.57%
# 12  -1.63646  0.017544  0.134713       0.55   24/82  13.11%
# 13  1.620728       0.0  0.197238       0.48   11/34  12.27%
# 14 -1.602095       0.0  0.170257       0.67  41/156  14.40%
# 15  1.592282  0.023256  0.183799       0.55   32/53  35.99%
# 16  1.579701  0.037037  0.171951       0.58    8/16  20.93%
# 17  1.574929       0.0   0.15234       0.59   19/32  32.73%
# 18 -1.565262  0.018182   0.22087       0.79    7/24   9.04%
# 19 -1.554075  0.015625    0.2241       0.87   17/84   9.05%
# 20 -1.552404    0.0625  0.212004       0.88    7/34   6.81%
# 21 -1.550928  0.015625  0.199331       0.89  39/101  19.89%
#
#                                            Lead_genes
# 0   TGFBR1;TCF7;CDH1;TCF7L1;EGFR;VCL;TJP1;TCF7L2;S...
# 1   COL4A1;COL4A2;LAMC2;FN1;NPNT;ITGB6;ITGA11;COL4...
# 2   COL4A1;COL4A2;MYL9;LAMC2;FN1;ITGB6;ITGA11;FLNC...
# 3   CLDN2;MYL9;TUBA4A;RDX;MSN;ARHGEF18;CGNL1;RUNX1...
# 4   VCAN;CLDN2;CDH4;ESAM;NRXN3;CDH2;CDH1;CADM1;SDC...
# 5   COL5A1;COL4A1;SLC7A7;COL4A2;FXYD2;COL7A1;COL4A...
# 7   COL4A1;COL4A2;ERBB3;BCL2L11;LAMC2;FN1;ITGB6;FG...
# 9   COL4A1;COL4A2;JAG1;LAMC2;FN1;ITGB6;ITGA11;TCF7...
# 10  PTGS2;CXCL3;MUC5AC;CXCL5;CXCL1;LCN2;CXCL8;FOSL...
# 11  CDH2;ITGB6;ITGA11;TCF7;TCF7L1;PKP2;ITGB4;CACNB...
# 12  COL4A1;COL4A2;SERPINE1;TGFBR1;FN1;COL4A3;COL1A...
# 13  GCLC;CP;FTH1;GCLM;SAT1;SLC39A8;GSS;GPX4;TFRC;P...
# 14  MYL9;F2;RDX;FN1;ITGB6;FGFR4;ITGA11;MSN;PDGFB;E...
# 15  UBE2T;EME1;FANCL;POLH;PMS2;RPA2;FANCG;MLH1;ATR...
# 16   TXNRD1;PAPSS2;TXNRD3;CTH;KYAT1;PSTK;KYAT3;SEPHS1
# 17  HEXB;MGAT4A;RPN2;ALG13;MAN1B1;TUSC3;ALG3;ALG2;...
# 18        FXYD2;HKDC1;MGAM;PIK3CD;ATP1A1;CACNA1D;AKT3
# 19  COL4A1;COL4A2;LAMC2;FN1;BIRC7;COL4A3;COL4A4;GA...
# 20           FXYD2;MT2A;TRPM6;MT1X;VDR;SLC26A6;ATP1A1
# 21  SLC16A2;FXYD2;ITGAV;PFKFB2;NOTCH2;PIK3CD;CTNNB...

# %%
a = pre_res.res2d

b = a[a['FDR q-val']<.25]
b
#.sort_values(by='NES')[:20]
pi3k = b[b['Term']=='PI3K-Akt signaling pathway']['Lead_genes'].values[0]
associated_genes = pi3k.split(';')

associated_genes
# Out:
# ['COL4A1',
#  'COL4A2',
#  'ERBB3',
#  'BCL2L11',
#  'LAMC2',
#  'FN1',
#  'ITGB6',
#  'FGFR4',
#  'PHLPP1',
#  'ITGA11',
#  'COL4A3',
#  'PDGFB',
#  'SGK1',
#  'THBS1',
#  'COL1A1',
#  'PIK3AP1',
#  'IL4R',
#  'COL4A4',
#  'CREB3L2',
#  'COL6A1',
#  'EGFR',
#  'ITGB4',
#  'PDGFA',
#  'EFNA1',
#  'EFNA2',
#  'ITGAV',
#  'SGK2',
#  'COL6A2',
#  'MAGI1',
#  'ITGA5',
#  'GNB4',
#  'PHLPP2',
#  'GNG4',
#  'PIK3CD',
#  'LAMA5',
#  'LAMB3',
#  'CREB1',
#  'IGF1R',
#  'GSK3B',
#  'VEGFA',
#  'NFKB1',
#  'ITGA4',
#  'LPAR2',
#  'AKT3']

# %% [markdown]
# # GSEA with MSigDB

# %%
samp_dict = {'L156F_24hrs_vs_L156F_no_drug':'rnaseq_data_deseq2/L156F_24hours_vs_L156F_no_drug.csv',
'L156F_48hrs_vs_L156F_no_drug':'rnaseq_data_deseq2/L156F_48hours_vs_L156F_no_drug.csv',
'NT_24hrs_vs_NT_no_drug':'rnaseq_data_deseq2/NT_24hours_vs_NT_no_drug.csv',
'NT_48hrs_vs_NT_no_drug':'rnaseq_data_deseq2/NT_48hours_vs_NT_no_drug.csv',
'L156F_no_drug_vs_NT_no_drug':'rnaseq_data_deseq2/L156F_no_drug_vs_NT_no_drug.csv'}

samples = list(samp_dict.keys())

tx2gene = pd.read_csv("rnaseq_data_deseq2/tx2gene.tsv", sep='\t')
gene_name_dict = dict(zip(tx2gene['gene_id'], tx2gene['gene_name']))

filtered_holder = []
unfiltered_holder = []

basemean_cutoff = 20

for i in samples:

    file = samp_dict[i]
    df = pd.read_csv(file).rename(columns={'Unnamed: 0':'gene_id'})
    df['gene_name'] = [gene_name_dict[i] for i in df['gene_id']]

    df2 = df[df['baseMean']>=basemean_cutoff]
    df2 = df2.set_index('gene_name')

    print(f'{len(df2)}/{len(df)}')

    filtered_holder.append(df2)
    unfiltered_holder.append(df)

filtered_dict = dict(zip(samples, filtered_holder))
unfiltered_dict = dict(zip(samples, unfiltered_holder))
# Out:
# 15737/35965
# 15794/36094
# 16097/38233
# 15975/37525
# 15672/35867

# %%
aa = filtered_dict['NT_24hrs_vs_NT_no_drug'].reset_index()
aa[aa['gene_name']=='CDK9']
# Out:
#      gene_name             gene_id     baseMean  log2FoldChange     lfcSE  \
# 5614      CDK9  ENSG00000136807.14  1944.945496          0.3125  0.083731
#
#           stat   pvalue      padj
# 5614  3.732184  0.00019  0.000893

# %%
msig.list_category(dbver="2024.1.Hs")
# Out:
# ['c1.all',
#  'c2.all',
#  'c2.cgp',
#  'c2.cp.biocarta',
#  'c2.cp.kegg_legacy',
#  'c2.cp.kegg_medicus',
#  'c2.cp.pid',
#  'c2.cp.reactome',
#  'c2.cp',
#  'c2.cp.wikipathways',
#  'c3.all',
#  'c3.mir.mir_legacy',
#  'c3.mir.mirdb',
#  'c3.mir',
#  'c3.tft.gtrd',
#  'c3.tft.tft_legacy',
#  'c3.tft',
#  'c4.3ca',
#  'c4.all',
#  'c4.cgn',
#  'c4.cm',
#  'c5.all',
#  'c5.go.bp',
#  'c5.go.cc',
#  'c5.go.mf',
#  'c5.go',
#  'c5.hpo',
#  'c6.all',
#  'c7.all',
#  'c7.immunesigdb',
#  'c7.vax',
#  'c8.all',
#  'h.all',
#  'msigdb']

# %%
from gseapy import Msigdb

msig = Msigdb()
#msig.list_dbver()

#msig.list_category(dbver="2024.1.Hs") 

#gmt = msig.get_gmt(category='h.all', dbver="2024.1.Hs") #hallmarks

#trying the canonical pathways
#gmt = msig.get_gmt(category='c2.cp', dbver="2024.1.Hs") #canonical pathways

#gmt = msig.get_gmt(category='c2.cp.kegg_legacy', dbver="2024.1.Hs") #kegg legacy
#could try chemical and genetic perturbations
#gmt = msig.get_gmt(category='c2.cgp', dbver="2024.1.Hs") #hchemical and genetic perturbations


gmt = msig.get_gmt(category='c6.all', dbver="2024.1.Hs") #oncogenic gene sets

# Prepare the input: the GSEA input expects a series with gene names as the index and log2FoldChange as the values
gsea_results = []
for samp in samples:
    df2 = filtered_dict[samp]

    ranking = df2[["stat"]]
    ranking = ranking.sort_values("stat", ascending=False)


    # Run pre-ranked GSEA
    pre_res2 = gs.prerank(
        rnk=ranking,
        gene_sets=gmt,  # or "GO_Biological_Process_2018", etc.'KEGG_2021_Human'
        outdir="gsea_output",   # output directory
        permutation_num=100,    # reduce for speed, increase for publication
        seed=42
    )

    gsea_results.append(pre_res2.res2d)

gsea_dict = dict(zip(samples, gsea_results))
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
options = ['L156F_24hrs_vs_L156F_no_drug',
 'L156F_48hrs_vs_L156F_no_drug',
 'NT_24hrs_vs_NT_no_drug',
 'NT_48hrs_vs_NT_no_drug',
 'L156F_no_drug_vs_NT_no_drug']

a1 = gsea_dict['L156F_no_drug_vs_NT_no_drug']

a1[:40]
# Out:
#        Name                                Term        ES       NES NOM p-val  \
# 0   prerank                       TGFB_UP.V1_UP -0.613004 -2.422422       0.0
# 1   prerank  CORDENONSI_YAP_CONSERVED_SIGNATURE -0.606186 -2.113118       0.0
# 2   prerank             ESC_V6.5_UP_EARLY.V1_DN -0.497519 -1.960691       0.0
# 3   prerank                      CAHOY_NEURONAL  0.567312  1.952096       0.0
# 4   prerank                    CAHOY_ASTROGLIAL  -0.51508 -1.900767       0.0
# 5   prerank              CAHOY_OLIGODENDROCUTIC -0.512013 -1.858816       0.0
# 6   prerank                      BRCA1_DN.V1_UP  0.541784  1.835503       0.0
# 7   prerank                      NOTCH_DN.V1_UP -0.475409 -1.810648       0.0
# 8   prerank                ESC_J1_UP_LATE.V1_UP -0.456158 -1.800441       0.0
# 9   prerank                  PRC2_EZH2_UP.V1_UP  0.416387  1.771562       0.0
# 10  prerank              BMI1_DN_MEL18_DN.V1_UP -0.488596 -1.755503       0.0
# 11  prerank                       LEF1_UP.V1_UP -0.457872 -1.749049       0.0
# 12  prerank                   KRAS.600_UP.V1_DN  -0.45051 -1.720673       0.0
# 13  prerank                  BCAT_BILD_ET_AL_UP -0.553418 -1.715925  0.018868
# 14  prerank                       SNF5_DN.V1_DN  -0.45509 -1.706759       0.0
# 15  prerank                      ERBB2_UP.V1_UP  0.399732  1.702596       0.0
# 16  prerank                           NFE2L2.V2  0.382229  1.697875       0.0
# 17  prerank                   KRAS.600_UP.V1_UP  0.387966  1.676377       0.0
# 18  prerank                        CRX_DN.V1_DN -0.444882   -1.6488       0.0
# 19  prerank                    RB_P107_DN.V1_UP -0.435538  -1.64653       0.0
# 20  prerank              ESC_V6.5_UP_LATE.V1_UP -0.405655 -1.637931       0.0
# 21  prerank                        P53_DN.V1_DN -0.424118 -1.634006       0.0
# 22  prerank                   PRC2_EED_DN.V1_DN -0.393792 -1.617673       0.0
# 23  prerank              BMI1_DN_MEL18_DN.V1_DN  0.381109   1.60994       0.0
# 24  prerank                    TBK1.DN.48HRS_UP  0.460941  1.588807       0.0
# 25  prerank                       BMI1_DN.V1_UP -0.411779 -1.566441  0.015873
# 26  prerank                         RB_DN.V1_DN -0.419569  -1.56633       0.0
# 27  prerank                        JNK_DN.V1_UP -0.383087 -1.552184       0.0
# 28  prerank                     VEGF_A_UP.V1_UP -0.378258 -1.543788       0.0
# 29  prerank                        MEK_UP.V1_UP  0.359156  1.535047       0.0
# 30  prerank                       LTE2_UP.V1_DN -0.392093 -1.534722       0.0
# 31  prerank                KRAS.BREAST_UP.V1_DN -0.434342 -1.523523  0.032787
# 32  prerank           KRAS.LUNG.BREAST_UP.V1_DN  -0.43638 -1.514263  0.035714
# 33  prerank                       CTIP_DN.V1_UP  0.440062  1.502764  0.046512
# 34  prerank                        P53_DN.V1_UP -0.375079 -1.497901       0.0
# 35  prerank                   KRAS.300_UP.V1_DN -0.445772 -1.494655  0.019608
# 36  prerank                  CYCLIN_D1_UP.V1_UP -0.383652 -1.493761       0.0
# 37  prerank                       PDGF_UP.V1_DN   -0.4306 -1.493547   0.04918
# 38  prerank                      MEL18_DN.V1_DN  0.365577   1.49339       0.0
# 39  prerank                        JNK_DN.V1_DN -0.396499 -1.491599  0.014706
#
#    FDR q-val FWER p-val   Tag %  Gene %  \
# 0        0.0        0.0  58/146   9.25%
# 1        0.0        0.0   20/55   8.30%
# 2        0.0        0.0  37/117  10.77%
# 3        0.0        0.0   16/45   5.93%
# 4        0.0        0.0   18/71   4.72%
# 5   0.001914       0.01   23/76  11.17%
# 6   0.005311       0.01   11/46   4.78%
# 7   0.006381       0.04  24/105   8.24%
# 8    0.00547       0.04  38/134   9.94%
# 9   0.010622       0.03  54/136  15.04%
# 10  0.011965        0.1  40/115  11.48%
# 11  0.011699       0.11  41/135  11.26%
# 12  0.012444       0.13  39/116  12.90%
# 13  0.011312       0.13   10/41  13.70%
# 14  0.011965       0.14   28/98   9.93%
# 15  0.023899       0.09  51/167  13.72%
# 16  0.019119       0.09  88/297  14.26%
# 17  0.024784       0.13  49/142  13.66%
# 18   0.01988       0.22   26/93  12.19%
# 19  0.019144       0.23  13/109   4.75%
# 20   0.02042       0.27  32/140   9.20%
# 21  0.019144       0.27  30/154   5.17%
# 22   0.02027       0.27  36/173  13.45%
# 23  0.045521       0.28   23/97   8.64%
# 24  0.053108       0.33    9/49   7.10%
# 25  0.037756       0.44  32/119  11.43%
# 26  0.035769       0.44  29/103  10.71%
# 27  0.040202       0.51  28/113  12.31%
# 28  0.040567       0.52  46/138  17.36%
# 29  0.084972       0.51  37/174   7.43%
# 30  0.044814       0.57  38/171  10.80%
# 31  0.049108       0.64   26/70  18.04%
# 32  0.052646       0.69   31/69  17.82%
# 33  0.096656       0.59    8/46   3.07%
# 34  0.058963       0.74  44/155  12.03%
# 35  0.058536       0.75   25/67  12.90%
# 36  0.056368       0.75  22/132   8.23%
# 37  0.054355       0.75   13/67   6.74%
# 38  0.092697        0.6   22/95   8.30%
# 39  0.053141       0.76  38/121  16.71%
#
#                                            Lead_genes
# 0   TAGLN;IL11;SLC17A3;PHLDB1;FGB;ETS2;CCN2;PMEPA1...
# 1   TNS1;SERPINE1;CCN2;FSTL1;DAB2;TGM2;COL4A3;SGK1...
# 2   CCDC80;TAGLN;COL4A1;COL4A2;SERPINE1;CCN2;LAMC2...
# 3   SCG2;GREM2;DRD1;MAL2;SYT1;KIAA0319;RASGEF1A;ST...
# 4   COL5A1;TAGLN;SERPINE1;VLDLR;GLIPR2;LTBP2;TMEM3...
# 5   PHLDB1;SPEG;ERBB3;CCN2;TUBA4A;WIPF1;MYRF;FSTL1...
# 6   TNC;MAP2;FCGBP;ISYNA1;HMGA2;SLCO1A2;SLC16A6;RP...
# 7   TNS1;COL4A1;NPTX1;RASGRP1;MN1;TGFBR1;INAVA;CRY...
# 8   COL4A1;HNF4A;COL4A2;FGB;CCN2;VIL1;DAB2;GLIPR1;...
# 9   SEMA3A;ASIC2;ANGPTL4;PIR;ARL4C;NR4A2;OSGIN1;MC...
# 10  TAGLN;JAG1;VLDLR;NAV2;MGLL;ADAM19;TRIO;PMEPA1;...
# 11  IL11;SERPINE1;CDA;MYL9;PCSK5;ADAM19;FN1;PMEPA1...
# 12  TAGLN;MATN2;TM4SF4;ACKR3;MYL9;NRXN3;EDN2;ADAMT...
# 13  TAGLN;MYL9;PALMD;FHDC1;SIRPA;FOXQ1;B4GALT1;STX...
# 14  ANXA8;IL11;SPEG;TINAGL1;FBLIM1;EFEMP1;RBP4;NNM...
# 15  PARM1;AQP3;GDF15;DUSP4;ANGPTL4;ASPH;APLP1;CYP1...
# 16  MAP2;ALDH3A1;CYP4F11;NR0B1;F2RL2;TRIML2;PIR;GC...
# 17  CHGB;SEMA3A;COL26A1;PTGS2;DUSP4;MMD;ANGPTL4;AR...
# 18  COL4A2;HNF1A;GLIPR2;RBP4;JUNB;TGM2;KSR1;MYOCD;...
# 19  COL5A1;TAGLN;CDH2;FSTL1;EDN2;DUSP1;COL1A1;ABAT...
# 20  COL4A1;COL4A2;FGB;FXYD2;VIL1;CDH2;DAB2;RBP4;H1...
# 21  VCAN;HGD;TM4SF4;GFRA1;VLDLR;FGB;GLDC;MGLL;MITF...
# 22  CA9;TGFBR1;PFKFB4;CRYBG2;RNF19A;RDH5;DNAJB2;PL...
# 23  AQP3;SOX2;SERPINI1;KCNV1;ACOX2;DIRAS3;TSPAN1;I...
# 24  SOX2;ARL4C;BAMBI;EDN1;P4HTM;CHEK2;SCP2;CXCL2;D...
# 25  TAGLN;JAG1;ACKR3;VLDLR;GABRE;TRIO;PMEPA1;COL7A...
# 26  ACKR3;TUBA4A;LAMC2;IGFBP3;PDGFB;S100A16;BHLHE4...
# 27  SLC7A7;TRIM31;SLC16A2;ACKR3;IGFBP3;B3GALT5;HR;...
# 28  TAGLN;MATN2;IL32;MYL9;MN1;CORO2B;CLIP2;SDC4;OP...
# 29  PARM1;AQP3;GDF15;ALDH3A1;DUSP4;PEG10;ANGPTL4;A...
# 30  MATN2;JAG1;GFRA1;NAV2;BCL2L11;WIPF1;EPB41L2;EF...
# 31  TM4SF4;MYL9;SYNDIG1;CLSTN3;SIDT1;PDE3A;FRAS1;M...
# 32  TM4SF4;ACKR3;MYL9;SYNDIG1;SIDT1;PDE3A;DEFB1;FR...
# 33    MYOM1;CD22;INA;PDGFRL;PPEF1;FSTL4;CXCL8;ONECUT2
# 34  SLC16A2;TGFBI;CLTCL1;TUBA4A;EFEMP1;FHL2;RBP1;P...
# 35  TAGLN;TM4SF4;ACKR3;MYL9;GBP1;SIDT1;MAML3;CACNA...
# 36  TAGLN;CA9;COL4A2;KIAA1549L;ETS2;FHL2;MSN;KSR1;...
# 37  ITGB6;FBN2;AOX1;TUBA4B;TIMP3;BHLHE40;HERC3;EDN...
# 38  AQP3;SOX2;SERPINI1;ASIC2;TENT5A;DIRAS3;PHYH;CR...
# 39  RND1;TM4SF4;MYL9;BCL2L11;WIPF1;FXYD2;NRP2;MAP1...

# %%
plt.figure(figsize=(5,10
                    ))
sns.barplot(data = a1[a1['FDR q-val']<.02], x='NES', y='Term')
# Out:
# <Axes: xlabel='NES', ylabel='Term'>

# %%
a1[a1['Term']=='SWEET_KRAS_ONCOGENIC_SIGNATURE']
# Out:
#          Name                            Term        ES       NES NOM p-val  \
# 2051  prerank  SWEET_KRAS_ONCOGENIC_SIGNATURE -0.254371 -0.950773  0.533333
#
#      FDR q-val FWER p-val  Tag %  Gene %  \
# 2051  0.659643        1.0  16/77  16.70%
#
#                                              Lead_genes
# 2051  TGFBI;NPC2;MT2A;ID2;SIRPA;RO60;ACLY;HNF1B;HIF1...

# %%
gmt = msig.get_gmt(category='c2.cp', dbver="2024.1.Hs")

# %%
sample_names = ['L156F: 100 nM PROTAC 24 hours\nvs. No Drug',
                'L156F: 100 nM PROTAC 48 hours\nvs. No Drug',
                'NT gRNA: 100 nM PROTAC 24 hours\nvs. No Drug',
                'NT gRNA: 100 nM PROTAC 48 hours\nvs. No Drug',
                'L156F vs. NT gRNA (No Drug)']

samp_name_dict = dict(zip(samples, sample_names))
samp_name_dict
# Out:
# {'L156F_24hrs_vs_L156F_no_drug': 'L156F: 100 nM PROTAC 24 hours\nvs. No Drug',
#  'L156F_48hrs_vs_L156F_no_drug': 'L156F: 100 nM PROTAC 48 hours\nvs. No Drug',
#  'NT_24hrs_vs_NT_no_drug': 'NT gRNA: 100 nM PROTAC 24 hours\nvs. No Drug',
#  'NT_48hrs_vs_NT_no_drug': 'NT gRNA: 100 nM PROTAC 48 hours\nvs. No Drug',
#  'L156F_no_drug_vs_NT_no_drug': 'L156F vs. NT gRNA (No Drug)'}

# %%
fig, ax = plt.subplots(1,5, figsize=(20,5), sharey=False, sharex=True)

term = 'BRCA1_DN.V1_UP'
associated_genes = gmt[term]

for i in range(5):
    ax[i].spines[['top', 'right']].set_visible(False)
    ax[i].tick_params(axis='x', which='major', labelsize=15)
    ax[i].tick_params(axis='y', which='major', labelsize=15)
    ax[i].set_xlabel('LFC', fontsize=15)

ax[0].set_ylabel('$-log_{10}$(FDR)', fontsize=15)

for i, k in enumerate(samples):
    a = filtered_dict[k].reset_index()
    
    subset1 = a[a['gene_name'].isin(associated_genes)]
    other = a[~a['gene_name'].isin(associated_genes)]

    g_out = gsea_dict[k]
    
    NES  = np.round(g_out.loc[g_out['Term']==term, 'NES'].values[0],3)
    fdr_q = np.round(g_out.loc[g_out['Term']==term, 'FDR q-val'].values[0], 3)
    
    ax[i].scatter(other['log2FoldChange'], -np.log10(other['padj']), color='tab:grey', alpha=.2)
    ax[i].scatter(subset1['log2FoldChange'], -np.log10(subset1['padj']), color='tab:red', label=f'NES = {NES}\nFDR q-val = {fdr_q}', alpha=.5)
    ax[i].legend(fontsize=15)

    ax[i].set_title(samp_name_dict[k], fontsize=14)

    

fig.suptitle(term, fontsize=17)
fig.tight_layout()

# %%
samples
# Out:
# ['L156F_24hrs_vs_L156F_no_drug',
#  'L156F_48hrs_vs_L156F_no_drug',
#  'NT_24hrs_vs_NT_no_drug',
#  'NT_48hrs_vs_NT_no_drug',
#  'L156F_no_drug_vs_NT_no_drug']

# %%
k = 'L156F_no_drug_vs_NT_no_drug'
a = filtered_dict[k].reset_index()
    
subset1 = a[a['gene_name'].isin(associated_genes)]
other = a[~a['gene_name'].isin(associated_genes)]
subset1.sort_values(by='padj')[:20
                               ]
# Out:
#       gene_name             gene_id      baseMean  log2FoldChange     lfcSE  \
# 1167       TNS1  ENSG00000079308.21   1999.362624       -2.222871  0.123384
# 4811     COL5A1  ENSG00000130635.17   6904.394173       -1.987472  0.133448
# 6958      TAGLN  ENSG00000149591.17   1441.438764       -2.513226  0.169343
# 12338       LBH  ENSG00000213626.13   6649.578536       -1.419740  0.105425
# 11216    COL4A1  ENSG00000187498.17   3797.642752       -2.140666  0.164579
# 5045      MATN2  ENSG00000132561.14   1790.717693       -1.438885  0.125142
# 6041       TPM1  ENSG00000140416.26  25582.480108       -1.100177  0.102862
# 3308        HGD  ENSG00000113924.12   2203.717522       -1.277239  0.127036
# 5287     COL4A2  ENSG00000134871.20   9553.172141       -1.854633  0.184990
# 10362      CDH4  ENSG00000179242.16    697.543991       -2.351023  0.236598
# 2602   SERPINE1   ENSG00000106366.9  18203.241993       -1.150831  0.116863
# 6500      ACKR3   ENSG00000144476.6    335.631327       -1.920683  0.215432
# 3983      TGFBI  ENSG00000120708.17  70170.331741       -0.882602  0.106161
# 9469      NPTX1   ENSG00000171246.7   1045.988512       -1.071051  0.138344
# 1995       MYL9  ENSG00000101335.10    191.014426       -1.756781  0.242253
# 5125      EPHB2  ENSG00000133216.17   4184.059001       -1.234483  0.171136
# 3531      WIPF1  ENSG00000115935.19   1071.409165       -0.992591  0.146392
# 5317     ADAM19  ENSG00000135074.16   1050.664658       -0.953915  0.142315
# 4257     PMEPA1  ENSG00000124225.16  11341.721783       -1.180374  0.185395
# 8142     IGFBP7  ENSG00000163453.11   1676.376627       -0.795427  0.126815
#
#             stat        pvalue          padj
# 1167  -18.015855  1.463041e-72  2.765440e-68
# 4811  -14.893224  3.647500e-50  1.723626e-46
# 6958  -14.841049  7.950253e-50  3.005513e-46
# 12338 -13.466828  2.451740e-41  5.149199e-38
# 11216 -13.006933  1.117371e-38  1.760046e-35
# 5045  -11.497980  1.350393e-30  1.418063e-27
# 6041  -10.695696  1.066157e-26  8.061000e-24
# 3308  -10.054128  8.809792e-24  5.371700e-21
# 5287  -10.025589  1.176561e-23  6.949799e-21
# 10362  -9.936767  2.880231e-23  1.649761e-20
# 2602   -9.847701  7.012999e-23  3.682214e-20
# 6500   -8.915502  4.856095e-19  1.873264e-16
# 3983   -8.313813  9.267523e-17  2.694996e-14
# 9469   -7.741949  9.790397e-15  2.229615e-12
# 1995   -7.251852  4.111099e-13  7.929388e-11
# 5125   -7.213468  5.454436e-13  1.030997e-10
# 3531   -6.780346  1.198887e-11  1.798520e-09
# 5317   -6.702852  2.043908e-11  2.861774e-09
# 4257   -6.366814  1.929954e-10  2.323566e-08
# 8142   -6.272337  3.556681e-10  4.025652e-08

# %%
fig, ax = plt.subplots(1,5, figsize=(20,5), sharey=True, sharex=True)

term = 'REACTOME_MAP2K_AND_MAPK_ACTIVATION'
associated_genes = gmt[term]

for i in range(5):
    ax[i].spines[['top', 'right']].set_visible(False)
    ax[i].tick_params(axis='x', which='major', labelsize=15)
    ax[i].tick_params(axis='y', which='major', labelsize=15)
    ax[i].set_xlabel('LFC', fontsize=15)

ax[0].set_ylabel('$-log_{10}$(FDR)', fontsize=15)

for i, k in enumerate(samples):
    a = filtered_dict[k].reset_index()
    subset_low = a[(a['log2FoldChange']<=-1) & (a['padj']<=.01)]
    #subset_high = a[a['gene_name'].isin(associated_genes)]
    subset_high = a[(a['log2FoldChange']>=1) & (a['padj']<=.01)]

    idx_de = pd.concat((subset_low, subset_high))

    a_no_change = a.drop(list(idx_de.index), axis=0)
    
    
    ax[i].scatter(a_no_change['log2FoldChange'], -np.log10(a_no_change['padj']), color='tab:grey', alpha=.2)
    ax[i].scatter(subset_high['log2FoldChange'], -np.log10(subset_high['padj']), color='tab:red', label=f'{len(subset_high)} DE UP', alpha=.5)
    ax[i].scatter(subset_low['log2FoldChange'], -np.log10(subset_low['padj']), color='tab:blue', label=f'{len(subset_low)} DE DOWN', alpha=.5)

    ax[i].legend(fontsize=15)

    ax[i].set_title(samp_name_dict[k], fontsize=14)

    
fig.tight_layout()

# %%
samples
# Out:
# ['L156F_24hrs_vs_L156F_no_drug',
#  'L156F_48hrs_vs_L156F_no_drug',
#  'NT_24hrs_vs_NT_no_drug',
#  'NT_48hrs_vs_NT_no_drug',
#  'L156F_no_drug_vs_NT_no_drug']

# %%
a = filtered_dict['NT_24hrs_vs_NT_no_drug'].reset_index()

b = filtered_dict['NT_48hrs_vs_NT_no_drug'].reset_index()

subset_low_24 = a[(a['log2FoldChange']<=-1) & (a['padj']<=.01)]
#subset_high = a[a['gene_name'].isin(associated_genes)]
subset_high_24 = a[(a['log2FoldChange']>=1) & (a['padj']<=.01)]

subset_low_48 = b[(b['log2FoldChange']<=-1) & (b['padj']<=.01)]
#subset_high = a[a['gene_name'].isin(associated_genes)]
subset_high_48 = b[(b['log2FoldChange']>=1) & (b['padj']<=.01)]

# %%
from matplotlib_venn import venn2

list1 = list(subset_high_24['gene_name'])
list2 = list(subset_high_48['gene_name'])

venn2([set(list1), set(list2)], set_labels=('24 hours UP', '48 hours UP'))

# %%
list1 = list(subset_low_24['gene_name'])
list2 = list(subset_low_48['gene_name'])

venn2([set(list1), set(list2)], set_labels=('24 hours DOWN', '48 hours DOWN'))

# %%
k = 'L156F_48hrs_vs_L156F_no_drug'
a = filtered_dict[k].reset_index()
a[a['padj']<.01]
# Out:
#              gene_name             gene_id     baseMean  log2FoldChange  \
# 217          NME1-NME2  ENSG00000011052.21   395.523809        0.964664
# 290              RGPD5  ENSG00000015568.13   218.888461        1.752475
# 1476              CHGB  ENSG00000089199.10   954.302309       -0.828263
# 1905            BDKRB1  ENSG00000100739.11   216.492565       -0.998174
# 4003              EGR1   ENSG00000120738.8   120.109982       -1.398671
# 5801              RBP4  ENSG00000138207.15   528.681076       -0.948417
# 12500           MUC5AC   ENSG00000215182.8  2325.484085       -1.254484
# 12973          GOLGA8N   ENSG00000232653.9    88.621222       -1.979567
# 12976        GTF2I-AS1   ENSG00000232729.9    54.615185        4.072053
# 14550  ENSG00000273711   ENSG00000273711.2    24.792720        5.167415
#
#           lfcSE      stat        pvalue          padj
# 217    0.174335  5.533408  3.140681e-08  2.175199e-04
# 290    0.335991  5.215831  1.829949e-07  7.608788e-04
# 1476   0.142126 -5.827646  5.621450e-09  7.743547e-05
# 1905   0.208462 -4.788272  1.682233e-06  3.862127e-03
# 4003   0.268760 -5.204170  1.948656e-07  7.608788e-04
# 5801   0.183064 -5.180793  2.209448e-07  7.608788e-04
# 12500  0.187666 -6.684670  2.314452e-11  6.376316e-07
# 12973  0.387294 -5.111274  3.199940e-07  9.795371e-04
# 12976  0.815134  4.995566  5.866353e-07  1.469255e-03
# 14550  0.934022  5.532433  3.158184e-08  2.175199e-04

# %%
a = filtered_dict[k].reset_index()
subset_low = a[(a['log2FoldChange']<=-1) & (a['padj']<=.01)]
#subset_high = a[a['gene_name'].isin(associated_genes)]
subset_high = a[(a['log2FoldChange']>=1) & (a['padj']<=.01)]

idx_de = pd.concat((subset_low, subset_high))

a_no_change = a.drop(list(idx_de.index), axis=0)
# Out:
#              gene_name             gene_id     baseMean  log2FoldChange  \
# 0               TSPAN6  ENSG00000000003.16  1422.589780       -0.019971
# 1                 DPM1  ENSG00000000419.14  1348.009095        0.315192
# 2                SCYL3  ENSG00000000457.14   305.355630        0.267467
# 3                FIRRM  ENSG00000000460.17   693.240995        0.075808
# 4                  CFH  ENSG00000000971.17  3683.131192       -0.094347
# ...                ...                 ...          ...             ...
# 15667  ENSG00000310534   ENSG00000310534.1    23.451927        0.365768
# 15668  ENSG00000310535   ENSG00000310535.1    63.493342        0.516733
# 15669  ENSG00000310536   ENSG00000310536.1    26.716057       -0.454655
# 15670  ENSG00000310537   ENSG00000310537.1    88.229341        0.151018
# 15671          DDX11L2   ENSG00000310539.1    62.839901        0.325887
#
#           lfcSE      stat    pvalue      padj
# 0      0.259572 -0.076938  0.938673  0.995481
# 1      0.223984  1.407207  0.159366  0.629373
# 2      0.221097  1.209729  0.226383  0.725928
# 3      0.226179  0.335168  0.737498  0.970244
# 4      0.185759 -0.507900  0.611523  0.944969
# ...         ...       ...       ...       ...
# 15667  0.749690  0.487892  0.625626  0.948693
# 15668  0.321945  1.605037  0.108486  0.526400
# 15669  0.455564 -0.998005  0.318277  0.809809
# 15670  0.320415  0.471319  0.637413  0.951482
# 15671  0.513331  0.634847  0.525528  0.920471
#
# [15359 rows x 8 columns]

# %%
a
# Out:
#              gene_name             gene_id     baseMean  log2FoldChange  \
# 0               TSPAN6  ENSG00000000003.16  1422.589780       -0.019971
# 1                 DPM1  ENSG00000000419.14  1348.009095        0.315192
# 2                SCYL3  ENSG00000000457.14   305.355630        0.267467
# 3                FIRRM  ENSG00000000460.17   693.240995        0.075808
# 4                  CFH  ENSG00000000971.17  3683.131192       -0.094347
# ...                ...                 ...          ...             ...
# 15667  ENSG00000310534   ENSG00000310534.1    23.451927        0.365768
# 15668  ENSG00000310535   ENSG00000310535.1    63.493342        0.516733
# 15669  ENSG00000310536   ENSG00000310536.1    26.716057       -0.454655
# 15670  ENSG00000310537   ENSG00000310537.1    88.229341        0.151018
# 15671          DDX11L2   ENSG00000310539.1    62.839901        0.325887
#
#           lfcSE      stat    pvalue      padj
# 0      0.259572 -0.076938  0.938673  0.995481
# 1      0.223984  1.407207  0.159366  0.629373
# 2      0.221097  1.209729  0.226383  0.725928
# 3      0.226179  0.335168  0.737498  0.970244
# 4      0.185759 -0.507900  0.611523  0.944969
# ...         ...       ...       ...       ...
# 15667  0.749690  0.487892  0.625626  0.948693
# 15668  0.321945  1.605037  0.108486  0.526400
# 15669  0.455564 -0.998005  0.318277  0.809809
# 15670  0.320415  0.471319  0.637413  0.951482
# 15671  0.513331  0.634847  0.525528  0.920471
#
# [15672 rows x 8 columns]

# %%
gmt = msig.get_gmt(category='c6.all', dbver="2024.1.Hs") #oncogenic gene sets

s = 'L156F_no_drug_vs_NT_no_drug'
aa = gsea_dict[s]

term = 'KRAS.600_UP.V1_UP'
associated_genes = gmt[term]

a = filtered_dict[s].reset_index()
    
subset1 = a[a['gene_name'].isin(associated_genes)]
subset1.sort_values(by='log2FoldChange')[:20]
# Out:
#        gene_name             gene_id      baseMean  log2FoldChange     lfcSE  \
# 118        USH1C  ENSG00000006611.17    428.185925       -2.757662  0.175085
# 5367        RDH5  ENSG00000135437.10     79.667411       -1.822172  0.324775
# 2972   KIAA1549L  ENSG00000110427.17    412.717621       -1.807473  0.182586
# 2902       TRIM2  ENSG00000109654.16     69.079268       -1.400726  0.387667
# 6060       NTRK3  ENSG00000140538.17   6258.743416       -1.170762  0.109548
# 10278       GLDC  ENSG00000178445.10   1063.415314       -0.997645  0.127378
# 5317      ADAM19  ENSG00000135074.16   1050.664658       -0.953915  0.142315
# 9296      KCNAB3  ENSG00000170049.10    103.511851       -0.888279  0.270979
# 5794        RBP4  ENSG00000138207.15    983.072246       -0.865543  0.159200
# 11985       TGM2  ENSG00000198959.12  77819.463378       -0.801231  0.163865
# 3018     CYP27B1  ENSG00000111012.12     65.985712       -0.785827  0.320427
# 4208        G0S2   ENSG00000123689.6     40.649258       -0.762407  0.417122
# 9032       KIF5C  ENSG00000168280.18     58.625031       -0.663439  0.419333
# 1481        LAG3   ENSG00000089692.9     50.580435       -0.623822  0.373716
# 11807     CSF2RA  ENSG00000198223.19     91.568595       -0.606784  1.706720
# 9811     C1QTNF1  ENSG00000173918.15   1560.104887       -0.604159  0.153721
# 13374    SIMC1P1   ENSG00000246596.8     27.228902       -0.596765  0.442174
# 3493       IL1R2  ENSG00000115590.14     40.591463       -0.585825  0.400127
# 2510       SCN1B  ENSG00000105711.14    499.894826       -0.572049  0.182671
# 5059      SNAP25  ENSG00000132639.15   1424.521177       -0.482735  0.184179
#
#             stat        pvalue          padj
# 118   -15.750429  6.821644e-56  4.298090e-52
# 5367   -5.610566  2.016658e-08  1.671880e-06
# 2972   -9.899315  4.191375e-23  2.330158e-20
# 2902   -3.613221  3.024162e-04  8.308534e-03
# 6060  -10.687210  1.168324e-26  8.493714e-24
# 10278  -7.832183  4.794713e-15  1.147211e-12
# 5317   -6.702852  2.043908e-11  2.861774e-09
# 9296   -3.278037  1.045318e-03  2.287806e-02
# 5794   -5.436837  5.423476e-08  4.175795e-06
# 11985  -4.889592  1.010452e-06  5.913176e-05
# 3018   -2.452434  1.418936e-02  1.574741e-01
# 4208   -1.827781  6.758236e-02  4.134116e-01
# 9032   -1.582129  1.136201e-01  5.383990e-01
# 1481   -1.669239  9.507009e-02  4.944077e-01
# 11807  -0.355526  7.221952e-01  9.667116e-01
# 9811   -3.930241  8.486093e-05  2.839011e-03
# 13374  -1.349616  1.771393e-01  6.584266e-01
# 3493   -1.464096  1.431676e-01  6.007001e-01
# 2510   -3.131585  1.738654e-03  3.377598e-02
# 5059   -2.621012  8.766925e-03  1.116660e-01

# %%
a = filtered_dict[s].reset_index()

a[a['gene_name'].isin(['KRAS', 'NRAS', 'HRAS', 'TP53', 'CTNNB1', 'MYC', 'YAP'])]
# Out:
#       gene_name             gene_id     baseMean  log2FoldChange     lfcSE  \
# 5204       KRAS  ENSG00000133703.14  1039.994172       -0.007209  0.107784
# 5663        MYC  ENSG00000136997.22  6774.314181        0.467043  0.046952
# 6223       TP53  ENSG00000141510.19  4139.966583        0.322820  0.053057
# 9101     CTNNB1  ENSG00000168036.19  8875.222729       -0.324209  0.043359
# 10013      HRAS  ENSG00000174775.18  3257.785193        0.752464  0.055351
# 12476      NRAS   ENSG00000213281.5  1965.530517        0.045822  0.093183
#
#             stat        pvalue          padj
# 5204   -0.066885  9.466730e-01  9.734854e-01
# 5663    9.947327  2.590479e-23  9.218508e-22
# 6223    6.084392  1.169345e-09  1.214469e-08
# 9101   -7.477297  7.586690e-14  1.240499e-12
# 10013  13.594291  4.329363e-42  4.250074e-40
# 12476   0.491739  6.229035e-01  7.741952e-01

# %%
s = 'NT_24hrs_vs_NT_no_drug'

a = filtered_dict[s].reset_index()
a.sort_values(by='padj')[:20]
# Out:
#              gene_name             gene_id      baseMean  log2FoldChange  \
# 8633             CLDN2  ENSG00000165376.12   3923.045245       -2.394273
# 212          NME1-NME2  ENSG00000011052.21   1865.490852        4.276233
# 4350            CDKN1A  ENSG00000124762.15  15530.959923        1.833353
# 11303           HEXIM1   ENSG00000186834.4   4626.199499       -2.638123
# 2735             ACTA2  ENSG00000107796.14   2785.775542        2.455542
# 15260  ENSG00000287001   ENSG00000287001.4   8621.834608        2.923651
# 7798              BTG2   ENSG00000159388.6   1810.260154        2.938985
# 1991            CDC25B  ENSG00000101224.18   9180.933622       -1.597237
# 4019              EGR1   ENSG00000120738.8   1524.385219        3.431742
# 2762              DKK1  ENSG00000107984.10   7086.479573       -1.814699
# 11698            DAPK1  ENSG00000196730.13   4802.276432       -1.525865
# 14602            SRXN1   ENSG00000271303.2  15953.811865        1.257429
# 8868              NNMT   ENSG00000166741.9   3043.718914       -1.838733
# 4741             MTUS1  ENSG00000129422.15   9363.635853       -1.748407
# 699               GPC1   ENSG00000063660.9  14342.684439        1.529374
# 4546             HSPA2  ENSG00000126803.10   3840.266496       -1.581342
# 9578              JUNB   ENSG00000171223.6   6344.176190        1.683341
# 2773             UBE2S  ENSG00000108106.14   9483.738830       -1.156554
# 5456              MDM2  ENSG00000135679.27   5734.874487        1.734079
# 2619          SERPINE1   ENSG00000106366.9  40748.787775        1.167716
#
#           lfcSE       stat         pvalue           padj
# 8633   0.062379 -38.382564   0.000000e+00   0.000000e+00
# 212    0.099636  42.918354   0.000000e+00   0.000000e+00
# 4350   0.043621  42.029561   0.000000e+00   0.000000e+00
# 11303  0.052707 -50.052561   0.000000e+00   0.000000e+00
# 2735   0.064539  38.047522   0.000000e+00   0.000000e+00
# 15260  0.068257  42.833000   0.000000e+00   0.000000e+00
# 7798   0.075461  38.947105   0.000000e+00   0.000000e+00
# 1991   0.043239 -36.939526  1.072798e-298  3.435904e-295
# 4019   0.098866  34.710992  5.377929e-264  1.531037e-260
# 2762   0.055222 -32.862023  7.670286e-237  1.965281e-233
# 11698  0.047934 -31.832521  2.297759e-222  5.352108e-219
# 14602  0.040046  31.399431  2.059871e-216  4.398168e-213
# 8868   0.059057 -31.134994  8.097520e-213  1.595959e-209
# 4741   0.058110 -30.087645  7.030316e-199  1.286648e-195
# 699    0.052099  29.354989  2.063690e-189  3.525058e-186
# 4546   0.055811 -28.333675  1.330202e-176  2.130152e-173
# 9578   0.060246  27.941292  8.411074e-172  1.267697e-168
# 2773   0.042594 -27.152676  2.354357e-162  3.351297e-159
# 5456   0.064333  26.954873  5.001283e-160  6.744362e-157
# 2619   0.043581  26.794391  3.756062e-158  4.811891e-155

# %%
aa = gsea_dict['L156F_no_drug_vs_NT_no_drug']
axs = pre_res2.plot(terms=term)

# %%
from scipy.stats import zscore


tpm = pd.read_csv('rnaseq_data_deseq2/salmon.merged.gene_tpm.tsv', sep='\t')

subset1 = tpm[tpm['gene_name'].isin(associated_genes)]

replicates =  ['L156F_no_drug_1', 'L156F_no_drug_2','L156F_no_drug_3',
               'L156F_24hours_1', 'L156F_24hours_2','L156F_24hours_3', 
               'L156F_48hours_1', 'L156F_48hours_2','L156F_48hours_3', 
               'NT_no_drug_1','NT_no_drug_2', 'NT_no_drug_3',
                 'NT_24hours_1', 'NT_24hours_2', 'NT_24hours_3',
       'NT_48hours_1', 'NT_48hours_2', 'NT_48hours_3', ]


df_zscore_row = subset1[replicates].apply(zscore, axis=1)

# %%
fig, ax = plt.subplots(figsize=(5,10))
# 3297       9.542808
# 3362       3.316676
# 3376      -4.351487
# 3446       2.998514
# 3603       3.504609
# 3659       7.023113
# 4372       3.429624
# 4402       7.021727
# 4474       6.595238
# 4570       5.505257
# 4690       9.183528
# 4933       4.443184
# 5486       8.738294
# 5730      -1.245222
# 5766       8.597416
# 6172      -0.376892
# 6984       1.932345
# 7048       3.755604
# 7296       4.103523
# 7327       5.628224
# 7524       4.711578
# 7541       4.730313
# 7557       5.162183
# 7986       5.026885
# 8449      -2.848276
# 8515       5.403253
# 9827       5.004742
# 10144      3.419447
# 10285      4.393238
# 11975      7.291457
# 12250      6.753037
# 12350      3.850145
# 12367      5.105693
# 12783      2.179481
# 12994      7.300642
# 13312      7.675096
# 14269      6.960760
# 15526     -0.333983
# 17095      8.414829
# 17351      3.051313
# 17810      3.739304
# 19742      2.047527

# %%
terms = pre_res2.res2d.Term
axs = pre_res2.plot(terms=terms[2]) # v1.0.5

# %%
term = 'HALLMARK_P53_PATHWAY'

pi3k = a2[a2['Term']==term]['Lead_genes'].values[0]
associated_genes = pi3k.split(';')

# %%
associated_genes = gmt[term]

# %%
#df = pd.read_csv('rnaseq_data_deseq2/L156F_no_drug_vs_NT_no_drug.csv').rename(columns={'Unnamed: 0':'gene_id'})

df = pd.read_csv(file).rename(columns={'Unnamed: 0':'gene_id'})
#df = pd.read_csv('rnaseq_data_deseq2/NT_24hours_vs_NT_no_drug.csv').rename(columns={'Unnamed: 0':'gene_id'})


df['gene_name'] = [gene_name_dict[i] for i in df['gene_id']]
df2 = df[df['baseMean']>=50]

# %%
subset1 = df2[df2['gene_name'].isin(associated_genes)]
other = df2[~df2['gene_name'].isin(associated_genes)]

# %%
plt.scatter(other['log2FoldChange'], -np.log10(other['padj']), color='tab:grey', alpha=.2)
plt.scatter(subset1['log2FoldChange'], -np.log10(subset1['padj']), color='tab:red', label=term, alpha=.5)
plt.legend()

# %% [markdown]
# # PCA

# %%
pca = pd.read_csv('rnaseq_data_deseq2/deseq2.pca.vals.txt', sep='\t')

pca['condition'] = [i[:-2] for i in pca['sample']]

samps = ['NT_no_drug','NT_24hours', 'NT_48hours', 'L156F_no_drug','L156F_24hours', 'L156F_48hours', ]
c_dict = {'L156F_24hours':'tab:red', 'L156F_48hours':'darkred', 'L156F_no_drug':'lightcoral', 'NT_24hours':'tab:blue', 'NT_48hours':'darkblue', 'NT_no_drug':'lightblue'}


fig, ax = plt.subplots(figsize=(6,6))
for i in samps:
    pca_subset = pca[pca['condition']==i]
    ax.scatter(pca_subset['PC1: 29% variance'], pca_subset['PC2: 17% variance'], label=i, c=c_dict[i], edgecolor='black', s=200)
ax.legend(bbox_to_anchor=(1,.75), fontsize=14)

ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_ylabel('PC2: 17% variance', fontsize=15)
ax.set_xlabel('PC1: 29% variance', fontsize=15)
# Out:
# Text(0.5, 0, 'PC1: 29% variance')

# %%
# Out:
# array(['L156F_24hours', 'L156F_48hours', 'L156F_no_drug', 'NT_24hours',
#        'NT_48hours', 'NT_no_drug'], dtype=object)
